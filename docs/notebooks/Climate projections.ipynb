# %% [markdown]
# # 2. Climate projections &mdash; CMIP6 change factors
#
# Workflow: **`analyze_projections.smk`** (WF2)

# %% [markdown]
# <div style="border-left:4px solid #999;padding:0.5em 0.9em;background:#f6f6f6">
# <b>Source only &mdash; outputs are not committed.</b><br>
# Run the notebook to see results, or read a rendered copy published as an
# Artifact. Outputs are cleared on commit
# (<code>dev/scripts/notebook_outputs.py --strip</code>) and their absence is
# enforced by <code>tests/test_notebook_outputs.py</code> on both CI legs.<br>
# Why: a notebook carrying figures embeds them as base64 and does not
# delta-compress, so every edit added megabytes to history permanently &mdash;
# these three were 8.8 MB, and one rename sweep that rewrote three short
# strings inside them cost a 7.1 MB push.
# </div>

# %% [markdown]
# ## What this workflow does
#
# WF2 answers one question: *for this basin, how much do the climate models expect
# temperature and precipitation to change by a given horizon?*
#
# 1. **Resolves the basin** &mdash; the same region expression WF1 used.
# 2. **Fetches a CMIP6 slice** per (model, scenario, member), for the reference
#    period and each future horizon.
# 3. **Reduces each slice** to a basin-average monthly series, cached by series
#    key.
# 4. **Derives change factors** &mdash; future against reference, absolute for
#    temperature and relative for precipitation, per model, scenario, horizon,
#    month and statistic.
# 5. **Plots** the ensemble, including the change-factor cloud.
#
# ### Where this sits in the method &mdash; read before using the numbers
#
# CST is a **bottom-up** stress test. The scenarios in notebook 3 come from a
# weather generator sweeping a temperature &times; precipitation grid, **not** from
# these GCM projections. Nothing WF2 produces drives a stress-test run.
#
# WF2 is a **plausibility overlay**. Its change factors tell you *where on the
# stress-test grid the climate models currently sit*, so a vulnerability found at,
# say, +2&nbsp;&deg;C and &minus;15&nbsp;% precipitation can be described as inside
# or outside the projected range. Swap the ensemble and the overlay moves; the
# response surface underneath does not.
#
# That separation is the point of scenario-neutral assessment, and it is lost the
# moment these factors are used to choose which perturbations to run.

# %% [markdown]
# ## Setup

# %%
# Standard library, plus the few third-party names the results cells need.
import json
import os
import subprocess
from pathlib import Path

import pandas as pd
import yaml
from IPython import display

# %%
# Work from the repository root.
#
# Snakemake resolves every path in a config relative to the directory it is
# invoked from, and the shipped configs are written against the repo root.
# Rather than hardcoding an install path -- which is what made the previous
# version of this notebook unrunnable for anyone but its author -- walk up from
# wherever the kernel started until the Snakefiles come into view.
def find_repo_root(marker: str = "build_model.smk") -> Path:
    for candidate in (Path.cwd(), *Path.cwd().parents):
        if (candidate / marker).exists():
            return candidate
    raise RuntimeError(
        f"could not find {marker} at or above {Path.cwd()}; "
        "start the kernel inside the blueearth_cst checkout"
    )


REPO_ROOT = find_repo_root()
os.chdir(REPO_ROOT)
print(REPO_ROOT)

# %%
# Snakemake runs take minutes, so stream the output rather than buffering it to
# the end of the cell.
#
# `check` raises on a nonzero exit. Without it a failed Snakemake call printed
# its error into the cell output and the cell still rendered as SUCCESSFUL, so
# the first symptom was a later `display.Image` raising on a file that was never
# written -- an error pointing at the wrong place, in a document whose reader is
# the least equipped to tell the difference. Pass `check=False` where a nonzero
# exit is expected, as `snakemake --unlock` gives when there is no lock.
def run(command: str, *, check: bool = True) -> int:
    print("$ " + command)
    print()
    with subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        shell=True,
        stderr=subprocess.STDOUT,
        bufsize=1,
        close_fds=True,
    ) as process:
        for line in iter(process.stdout.readline, b""):
            print(line.rstrip().decode("utf-8", errors="replace"))
    if check and process.returncode != 0:
        raise RuntimeError(
            f"command failed with exit code {process.returncode}: {command}"
        )
    return process.returncode

# %% [markdown]
# ## The settings file
#
# The same file as WF1 &mdash; one config drives all three workflows, and the
# `workflows:` section selects which blocks apply to which. WF2 reads `project:`,
# `shared:` and `workflows.analyze_projections`.

# %%
# The settings file this notebook runs against, and the paths derived from it
# that every later cell needs.
CONFIG = "test_case/project_config_rapid.yml"

cfg = yaml.safe_load(Path(CONFIG).read_text(encoding="utf-8"))
PROJECT_DIR = Path(cfg["project"]["project_dir"])
PROJECT_NAME = cfg.get("project_name") or PROJECT_DIR.name
print("config      :", CONFIG)
print("project_dir :", PROJECT_DIR)

# %%
# The settings file, in full. It is commented in place -- those comments are the
# documentation for each key, which is why this cell prints the shipped file
# rather than re-authoring a copy that could drift away from it.
print(Path(CONFIG).read_text(encoding="utf-8"))

# %% [markdown]
# ### Reading the `analyze_projections` block
#
# - **`clim_project: cmip6`** &mdash; the projection archive. Its catalog is
#   `project.data_sources_climate` (`config/catalogs/cmip6_data.yml`), which is
#   **generated** from a live listing of the public CMIP6 store. Do not hand-edit
#   it.
# - **`models`, `scenarios`, `members`** &mdash; the ensemble, as a full cross
#   product. Any CMIP6 model in the catalog works; the ones in this config are
#   examples, not a supported subset.
# - **`variables`** &mdash; per variable: which source field to read, its canonical
#   kind (`rate` vs `state`), its units, and **how change is expressed**. `precip`
#   is `relative` (a percentage), `temp` is `absolute` (degrees). This key decides
#   what the numbers in the output tables *mean*.
# - **`historical_year_range`** &mdash; the reference period. It ends in 2014
#   because that is where the CMIP6 *historical* experiment stops; a later end is
#   clipped back to it.
# - **`future_horizons`** &mdash; named windows, each `[start_year, end_year]`.
#   Name them for the assessment rather than the calendar. `mid` here is
#   2046&ndash;2054, chosen to match the window WF3 will actually force the model
#   over.
#
# Two models rather than one matters more than it looks: with a single model the
# multi-model reduction never runs, so a config that appears to work can be hiding
# a code path that has never executed.

# %% [markdown]
# ## The job graph

# %%
# Render the job graph. `scripts/plot_workflow_dag.py` wraps `snakemake --dag`
# and pipes it through graphviz, so the image lands inside the project's own
# logs/ rather than in whatever directory the shell happened to be in:
#
#     <project_dir>/logs/dag/<project_name>_wf<N>[_<experiment>]_dag.png
#
# Reading the graph before running is the cheapest way to see whether the config
# was understood the way you meant it.
run(f"python scripts/plot_workflow_dag.py -s analyze_projections.smk --configfile {CONFIG}")

# %%
DAG_PNG = PROJECT_DIR / "logs" / "dag" / f"{PROJECT_NAME}_wf2_dag.png"
display.Image(str(DAG_PNG))

# %% [markdown]
# ### The rules, and the config keys that tune them
#
# | Rule | What it does | Config keys that tune it |
# |---|---|---|
# | **2.01** `snapshot_config` | records the effective config under `<project_dir>/config/runs/analyze_projections/` | `project.project_dir` |
# | **2.02** `delineate_region` | the basin polygon &mdash; the same product WF1 builds, rebuilt here so WF2 can run standalone | `shared.basin.region` |
# | **2.03** `delineate_spatial_units` | the subcatchments the basin average is taken over | `shared.basin.region`, `shared.basin.resolution` |
# | **2.04** `fetch_gcm_slice` | one fetch per (model, scenario, member, window) | `workflows.analyze_projections.models`, `.scenarios`, `.members`, `.historical_year_range`, `.future_horizons`, `project.data_sources_climate` |
# | **2.05** `reduce_gcm_series` | grid &rarr; basin-average monthly series, cached per series key | `.variables` |
# | **2.06** `derive_change_factors` | future against reference, per month and statistic; writes the annual and monthly summary tables | `.variables` (the `change:` mode), `.future_horizons`, `.historical_year_range`, `.stats`, `shared.water_year_start` |
# | **2.07** `plot_gcm_timeseries` | the ensemble figures and the change-factor cloud | &mdash; |
# | **2.08** `gather_benchmarks`, **2.09** `gather_logs` | merge the per-rule parts | &mdash; |
#
# The expensive rule is **2.04**: it reads from a remote store, so a first run is
# network-bound. Reduced series are cached by series key, which makes adding a
# *horizon* to an existing ensemble cheap and adding a *model* not.
# `dev/scripts/prune_series_cache.py` reports cached series the current config no
# longer asks for (dry run by default; `--delete` is explicit).

# %% [markdown]
# ## Running
#
# WF2 talks to a remote store, so an individual model fetch can fail for reasons
# that have nothing to do with your config. `--keep-going` lets the rest of the
# ensemble finish instead of aborting on the first failure &mdash; and the
# composition table in the results section then records which members resolved and
# which did not.

# %%
run(f"snakemake --unlock -s analyze_projections.smk --configfile {CONFIG}", check=False)

# %%
run(f"snakemake all -n -s analyze_projections.smk --configfile {CONFIG}")

# %%
run(f"snakemake all -c 3 -s analyze_projections.smk --configfile {CONFIG} --keep-going")

# %% [markdown]
# ## Results

# %%
# What the run wrote. Noisy internal branches are skipped so the shape of the
# tree stays readable.
def show_tree(root: Path, skip=(".snakemake", "_parts", "_work"), max_files=8):
    root = Path(root)
    for path, dirs, files in os.walk(root):
        dirs[:] = sorted(d for d in dirs if d not in skip)
        rel = Path(path).relative_to(root)
        print(root.name + "/" if str(rel) == "." else f"{root.name}/{rel}")
        shown = sorted(f for f in files if not f.endswith(".xml"))
        for name in shown[:max_files]:
            print("  - " + name)
        if len(shown) > max_files:
            print(f"  ... {len(shown) - max_files} more")


CMIP_DIR = PROJECT_DIR / "data" / "climate" / "projections" / "cmip6"
show_tree(CMIP_DIR)

# %% [markdown]
# ### Which members actually resolved &mdash; read this first
#
# `composition.csv` is the ensemble's honesty record: one row per requested
# (model, scenario, member), with a `status` and, when that is not `resolved`, a
# `reason`.
#
# Check it before reading any change factor. An ensemble mean taken over three
# models when you asked for five is not an error you will see reported anywhere
# else.

# %%
composition = pd.read_csv(CMIP_DIR / "summary" / "composition.csv")
composition[
    ["model", "scenario", "member", "status", "reason", "tier", "n_reference_years"]
]

# %% [markdown]
# ### Annual change factors
#
# One row per (model, scenario, member, horizon, variable, statistic). Both an
# `absolute_value` and a `relative_value` are given on every row; which one is
# *meaningful* is set by that variable's `change:` mode &mdash; percent for
# precipitation, degrees for temperature. `reference_window` and `horizon_window`
# travel on each row too, so a number cannot be read against the wrong period.

# %%
annual = pd.read_csv(CMIP_DIR / "summary" / "cmip6_change_factors_annual.csv")
annual[annual["statistic"] == "mean"][
    [
        "model",
        "scenario",
        "horizon",
        "variable",
        "reference_value",
        "absolute_value",
        "relative_value",
        "units",
        "status",
    ]
].round(2)

# %% [markdown]
# **How to read this.** Take the temperature rows in degrees and the
# precipitation rows in percent, then look at the *spread between models* rather
# than their average. The spread is the useful quantity here: it is the width of
# the region of the stress-test grid that current projections consider plausible.
#
# A two-model ensemble gives you a range, not a distribution. Do not report the
# mean of two models as "the projection".

# %% [markdown]
# ### Monthly change factors
#
# The same quantity resolved by calendar month. This is where a seasonal shift
# shows up, and it is why the annual table alone is not enough: an annual
# precipitation change near zero routinely hides a wetter wet season and a drier
# dry season. For a water-resources system that is a far larger change than the
# annual number suggests.

# %%
monthly = pd.read_csv(CMIP_DIR / "summary" / "cmip6_change_factors_monthly.csv")
precip_monthly = monthly[
    (monthly["statistic"] == "mean") & (monthly["variable"] == "precip")
]
pivot = precip_monthly.pivot_table(
    index="month", columns="model", values="relative_value"
)
pivot.round(1)

# %%
ax = pivot.plot(kind="bar", figsize=(9, 3.5), width=0.8)
ax.set_ylabel("precipitation change (%)")
ax.set_xlabel("month")
ax.axhline(0, color="k", lw=0.8)
ax.set_title("Monthly precipitation change by model, mid horizon")
ax.figure.tight_layout()

# %% [markdown]
# ### The ensemble figures
#
# The change-factor cloud is the figure to carry forward. Each point is one
# (model, scenario, member, horizon) in temperature-change &times;
# precipitation-change space &mdash; the same axes the stress-test grid in notebook
# 3 is defined on. Overlay one on the other and you have the plausibility layer
# this workflow exists to produce.

# %%
display.Image(str(CMIP_DIR / "plots" / "cmip6_change_factor_cloud.png"))

# %%
display.display(
    display.Image(str(CMIP_DIR / "plots" / "cmip6_temp_monthly_change.png")),
    display.Image(str(CMIP_DIR / "plots" / "cmip6_precip_monthly_change.png")),
)

# %% [markdown]
# ---
#
# ## Next
#
# **[3. Climate stress test](<Climate Stress Test.ipynb>)** &mdash; the
# perturbation grid, the weather generator, and the response surface these change
# factors get overlaid on.
#
# Previous: **[1. Model building](<Model building.ipynb>)**.
